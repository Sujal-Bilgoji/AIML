# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.plot([5,6,7,8])
plt.xlabel
plt.ylabel('some numbers')
plt.show()
